# %%
import spacy

nlp = spacy.blank("en")
doc = nlp("Captain america ate 100$ of samosa. Then he said I can do this all day.")
for token in doc:
    print(token)
# Out:
# Captain
# america
# ate
# 100
# $
# of
# samosa
# .
# Then
# he
# said
# I
# can
# do
# this
# all
# day
# .

# %%
nlp.pipe_names
# Out:
# []

# %%
nlp = spacy.load("en_core_web_sm")
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x2c98b0874d0>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x2c9a4705910>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x2c9c4579e70>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x2c9a452a490>),
#  ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x2c9a4529bd0>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x2c9c457a110>)]

# %%
doc = nlp("Captain america ate 100$ of samosa. Then he said I can do this all day.")

for token in doc:
    print(token, "->", spacy.explain(token.pos_), "->", token.lemma_)
# Out:
# Captain -> proper noun -> Captain
# america -> proper noun -> america
# ate -> verb -> eat
# 100 -> numeral -> 100
# $ -> numeral -> $
# of -> adposition -> of
# samosa -> proper noun -> samosa
# . -> punctuation -> .
# Then -> adverb -> then
# he -> pronoun -> he
# said -> verb -> say
# I -> pronoun -> I
# can -> auxiliary -> can
# do -> verb -> do
# this -> pronoun -> this
# all -> determiner -> all
# day -> noun -> day
# . -> punctuation -> .

# %% [markdown]
# ##### Named Entity Recognition

# %%
doc = nlp("Tesla Inc is going to acquire twitter for $45 billion")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Tesla Inc ORG
# $45 billion MONEY

# %%
from spacy import displacy

displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is going to acquire twitter for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $45 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %%
nlp = spacy.load("fr_core_news_sm")
doc = nlp("Tesla Inc va racheter Twitter pour $45 milliards de dollars")
for ent in doc.ents:
    print(ent.text, "->", ent.label_, "->", spacy.explain(ent.label_))
# Out:
# Tesla Inc -> PER -> Named person or family.
# Twitter -> MISC -> Miscellaneous entities, e.g. events, nationalities, products or works of art

# %%
for token in doc:
    print(token, "->", token.pos_, "->", token.lemma_)
# Out:
# Tesla -> PROPN -> Tesla
# Inc -> PROPN -> Inc
# va -> VERB -> aller
# racheter -> VERB -> racheter
# Twitter -> VERB -> twitter
# pour -> ADP -> pour
# $ -> NOUN -> dollar
# 45 -> NUM -> 45
# milliards -> NOUN -> milliard
# de -> ADP -> de
# dollars -> NOUN -> dollar

# %%
source_nlp = spacy.load("en_core_web_sm")

nlp = spacy.blank("en")
nlp.add_pipe("ner", source=source_nlp)
nlp.pipe_names
# Out:
# ['ner']

# %%
doc = nlp("Tesla Inc is going to acquire twitter for $45 billion")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Tesla Inc ORG
# $45 billion MONEY
